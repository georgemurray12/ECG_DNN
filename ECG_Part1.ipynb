# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(in_features=187, out_features=256)
        self.relu1 = nn.ReLU()
        self.linear2 = nn.Linear(in_features=256, out_features=256)
        self.relu2 = nn.ReLU()
        self.norm3 = nn.BatchNorm1d(num_features=256)
        self.avgpool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.linear3 = nn.Linear(in_features=256//2, out_features=256)
        self.relu3 = nn.ReLU()
        self.norm4 = nn.BatchNorm1d(num_features=256)
        self.avgpool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.linear4 = nn.Linear(in_features=256//2, out_features=256)
        self.relu4 = nn.ReLU()
        self.norm5 = nn.BatchNorm1d(num_features=256)
        self.avgpool3 = nn.AvgPool1d(kernel_size=2, stride=2)
        self.linear5 = nn.Linear(in_features=256//2, out_features=256)
        self.relu5 = nn.ReLU()
        self.linear6 = nn.Linear(in_features=256, out_features=5)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.relu1(self.linear1(x))
        x = self.relu2(self.linear2(x))
        x = self.norm3(x)
        x = self.avgpool1(x)
        x = self.relu3(self.linear3(x))
        x = self.norm4(x)
        x = self.avgpool2(x)
        x = self.relu4(self.linear4(x))
        x = self.norm5(x)
        x = self.avgpool3(x)
        x = self.relu5(self.linear5(x))
        x = self.linear6(x)
        y_hat = self.softmax(x)
        return y_hat

# %%
model=Net()
x=torch.rand(10,1,187) #if network is CNN
z=model(x)
model
# Out:
# Net(
#   (linear1): Linear(in_features=187, out_features=256, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=256, out_features=256, bias=True)
#   (relu2): ReLU()
#   (norm3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (relu3): ReLU()
#   (norm4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (linear4): Linear(in_features=128, out_features=256, bias=True)
#   (relu4): ReLU()
#   (norm5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool3): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (linear5): Linear(in_features=128, out_features=256, bias=True)
#   (relu5): ReLU()
#   (linear6): Linear(in_features=256, out_features=5, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        #x=x.reshape(1,-1) if network is CNN
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
# Out:
# Net(
#   (linear1): Linear(in_features=187, out_features=256, bias=True)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=256, out_features=256, bias=True)
#   (relu2): ReLU()
#   (norm3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool1): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (relu3): ReLU()
#   (norm4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool2): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (linear4): Linear(in_features=128, out_features=256, bias=True)
#   (relu4): ReLU()
#   (norm5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (avgpool3): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (linear5): Linear(in_features=128, out_features=256, bias=True)
#   (relu5): ReLU()
#   (linear6): Linear(in_features=256, out_features=5, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.1973, 0.1976, 0.2013, 0.2011, 0.2027],
#         [0.1906, 0.1937, 0.1958, 0.2124, 0.2075],
#         [0.1994, 0.2005, 0.2075, 0.1943, 0.1983],
#         [0.2010, 0.2029, 0.2011, 0.1984, 0.1966],
#         [0.2051, 0.2023, 0.2014, 0.1939, 0.1972],
#         [0.2060, 0.2012, 0.1930, 0.1953, 0.2045],
#         [0.2065, 0.1880, 0.1966, 0.2014, 0.2076],
#         [0.2039, 0.1998, 0.2033, 0.1990, 0.1940],
#         [0.2031, 0.1953, 0.1998, 0.1953, 0.2065],
#         [0.1987, 0.1974, 0.2029, 0.1977, 0.2033]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): 
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    save_checkpoint('ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.611063
# epoch 0 training loss: 1.3778712749481201 acc: 0.6418234442836469
# epoch 0 validation acc: 0.27597404
# saved: ECG_MLP_Pytorch_epoch0.pt
# /var/folders/7m/m8y5x3654vsfvdr5zmpdl5v40000gn/T/ipykernel_7503/3076453557.py:13: RuntimeWarning: invalid value encountered in float_scalars
#   prec[n]=TP/(TP+FP)
# Train Epoch: 1 [0%]	Loss: 1.169258
# epoch 1 training loss: 1.1535859324715354 acc: 0.7662807525325616
# epoch 1 validation acc: 0.66883117
# saved: ECG_MLP_Pytorch_epoch1.pt
# Train Epoch: 2 [0%]	Loss: 1.063722
# epoch 2 training loss: 1.0988000197844072 acc: 0.8165701881331404
# epoch 2 validation acc: 0.78896105
# saved: ECG_MLP_Pytorch_epoch2.pt
# Train Epoch: 3 [0%]	Loss: 1.079627
# epoch 3 training loss: 1.0642722086472944 acc: 0.849493487698987
# epoch 3 validation acc: 0.8019481
# saved: ECG_MLP_Pytorch_epoch3.pt
# Train Epoch: 4 [0%]	Loss: 1.057929
# epoch 4 training loss: 1.0438454394990748 acc: 0.8686685962373372
# epoch 4 validation acc: 0.8084416
# saved: ECG_MLP_Pytorch_epoch4.pt
# Train Epoch: 5 [0%]	Loss: 1.099390
# epoch 5 training loss: 1.0360508236018093 acc: 0.8719247467438495
# epoch 5 validation acc: 0.8246753
# saved: ECG_MLP_Pytorch_epoch5.pt
# Train Epoch: 6 [0%]	Loss: 1.051920
# epoch 6 training loss: 1.018248357556083 acc: 0.8910998552821997
# epoch 6 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch6.pt
# Train Epoch: 7 [0%]	Loss: 1.028514
# epoch 7 training loss: 1.0123903182419864 acc: 0.8994211287988423
# epoch 7 validation acc: 0.8084416
# saved: ECG_MLP_Pytorch_epoch7.pt
# Train Epoch: 8 [0%]	Loss: 1.003455
# epoch 8 training loss: 1.0076759945262561 acc: 0.9044862518089725
# epoch 8 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch8.pt
# Train Epoch: 9 [0%]	Loss: 0.995703
# epoch 9 training loss: 0.9981208172711459 acc: 0.912807525325615
# epoch 9 validation acc: 0.8181818
# saved: ECG_MLP_Pytorch_epoch9.pt
# Train Epoch: 10 [0%]	Loss: 1.027987
# epoch 10 training loss: 0.9970488819209012 acc: 0.9117221418234442
# epoch 10 validation acc: 0.8181818
# saved: ECG_MLP_Pytorch_epoch10.pt
# Train Epoch: 11 [0%]	Loss: 1.025655
# epoch 11 training loss: 0.9891907681118358 acc: 0.9211287988422576
# epoch 11 validation acc: 0.8246753
# saved: ECG_MLP_Pytorch_epoch11.pt
# Train Epoch: 12 [0%]	Loss: 0.990317
# epoch 12 training loss: 0.9881731434301897 acc: 0.9200434153400868
# epoch 12 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch12.pt
# Train Epoch: 13 [0%]	Loss: 0.985750
# epoch 13 training loss: 0.984959136356007 acc: 0.9225759768451519
# epoch 13 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch13.pt
# Train Epoch: 14 [0%]	Loss: 1.026072
# epoch 14 training loss: 0.9824507995085283 acc: 0.9254703328509407
# epoch 14 validation acc: 0.8181818
# saved: ECG_MLP_Pytorch_epoch14.pt
# Train Epoch: 15 [0%]	Loss: 1.031195
# epoch 15 training loss: 0.9773884469812567 acc: 0.9298118668596237
# epoch 15 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch15.pt
# Train Epoch: 16 [0%]	Loss: 0.958401
# epoch 16 training loss: 0.9772497280077501 acc: 0.9290882778581766
# epoch 16 validation acc: 0.8149351
# saved: ECG_MLP_Pytorch_epoch16.pt
# Train Epoch: 17 [0%]	Loss: 0.989850
# epoch 17 training loss: 0.9753557958386161 acc: 0.9341534008683068
# epoch 17 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch17.pt
# Train Epoch: 18 [0%]	Loss: 0.938690
# epoch 18 training loss: 0.970838189125061 acc: 0.9352387843704776
# epoch 18 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch18.pt
# Train Epoch: 19 [0%]	Loss: 0.951171
# epoch 19 training loss: 0.9668589505282316 acc: 0.9406657018813314
# epoch 19 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch19.pt
# Train Epoch: 20 [0%]	Loss: 0.944778
# epoch 20 training loss: 0.9673102498054504 acc: 0.9392185238784371
# epoch 20 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch20.pt
# Train Epoch: 21 [0%]	Loss: 0.968723
# epoch 21 training loss: 0.9680135683579878 acc: 0.9392185238784371
# epoch 21 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch21.pt
# Train Epoch: 22 [0%]	Loss: 0.960070
# epoch 22 training loss: 0.9668691835620187 acc: 0.9388567293777135
# epoch 22 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch22.pt
# Train Epoch: 23 [0%]	Loss: 0.982451
# epoch 23 training loss: 0.9659148481759158 acc: 0.9413892908827786
# epoch 23 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch23.pt
# Train Epoch: 24 [0%]	Loss: 0.956575
# epoch 24 training loss: 0.9661302322691138 acc: 0.9399421128798843
# epoch 24 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch24.pt
# Train Epoch: 25 [0%]	Loss: 0.989216
# epoch 25 training loss: 0.9647232131524519 acc: 0.9406657018813314
# epoch 25 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch25.pt
# Train Epoch: 26 [0%]	Loss: 0.968829
# epoch 26 training loss: 0.9621966264464639 acc: 0.945369030390738
# epoch 26 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch26.pt
# Train Epoch: 27 [0%]	Loss: 1.000995
# epoch 27 training loss: 0.9616737474094738 acc: 0.942836468885673
# epoch 27 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch27.pt
# Train Epoch: 28 [0%]	Loss: 1.002297
# epoch 28 training loss: 0.9605375203219327 acc: 0.9457308248914617
# epoch 28 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch28.pt
# Train Epoch: 29 [0%]	Loss: 0.952163
# epoch 29 training loss: 0.9584710652177985 acc: 0.9475397973950795
# epoch 29 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch29.pt
# Train Epoch: 30 [0%]	Loss: 0.949195
# epoch 30 training loss: 0.9564433152025397 acc: 0.9489869753979739
# epoch 30 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch30.pt
# Train Epoch: 31 [0%]	Loss: 0.947497
# epoch 31 training loss: 0.9617860452695326 acc: 0.9450072358900145
# epoch 31 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch31.pt
# Train Epoch: 32 [0%]	Loss: 0.952684
# epoch 32 training loss: 0.9674065736207095 acc: 0.9403039073806078
# epoch 32 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch32.pt
# Train Epoch: 33 [0%]	Loss: 0.953376
# epoch 33 training loss: 0.9613705819303339 acc: 0.9431982633863966
# epoch 33 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch33.pt
# Train Epoch: 34 [0%]	Loss: 0.960544
# epoch 34 training loss: 0.9571655799042095 acc: 0.9486251808972503
# epoch 34 validation acc: 0.83116883
# saved: ECG_MLP_Pytorch_epoch34.pt
# Train Epoch: 35 [0%]	Loss: 0.964644
# epoch 35 training loss: 0.9553405073556033 acc: 0.9500723589001447
# epoch 35 validation acc: 0.8279221
# saved: ECG_MLP_Pytorch_epoch35.pt
# Train Epoch: 36 [0%]	Loss: 0.944378
# epoch 36 training loss: 0.9547753984277899 acc: 0.9518813314037626
# epoch 36 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch36.pt
# Train Epoch: 37 [0%]	Loss: 0.945773
# epoch 37 training loss: 0.9545191336761821 acc: 0.9518813314037626
# epoch 37 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch37.pt
# Train Epoch: 38 [0%]	Loss: 0.950210
# epoch 38 training loss: 0.9559056677601554 acc: 0.9504341534008683
# epoch 38 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch38.pt
# Train Epoch: 39 [0%]	Loss: 1.001172
# epoch 39 training loss: 0.9528590007261797 acc: 0.9529667149059334
# epoch 39 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch39.pt
# Train Epoch: 40 [0%]	Loss: 0.955321
# epoch 40 training loss: 0.9514361782507463 acc: 0.9547756874095513
# epoch 40 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch40.pt
# Train Epoch: 41 [0%]	Loss: 0.962762
# epoch 41 training loss: 0.9473505263978784 acc: 0.9591172214182344
# epoch 41 validation acc: 0.83441556
# saved: ECG_MLP_Pytorch_epoch41.pt
# Train Epoch: 42 [0%]	Loss: 0.959066
# epoch 42 training loss: 0.9505183534188704 acc: 0.9558610709117221
# epoch 42 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch42.pt
# Train Epoch: 43 [0%]	Loss: 0.924665
# epoch 43 training loss: 0.9507517868822272 acc: 0.9558610709117221
# epoch 43 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch43.pt
# Train Epoch: 44 [0%]	Loss: 0.913135
# epoch 44 training loss: 0.9470539797436107 acc: 0.9583936324167872
# epoch 44 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch44.pt
# Train Epoch: 45 [0%]	Loss: 0.975070
# epoch 45 training loss: 0.9487650773741982 acc: 0.9562228654124457
# epoch 45 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch45.pt
# Train Epoch: 46 [0%]	Loss: 0.995500
# epoch 46 training loss: 0.9491665390404788 acc: 0.9562228654124457
# epoch 46 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch46.pt
# Train Epoch: 47 [0%]	Loss: 0.959414
# epoch 47 training loss: 0.947816011580554 acc: 0.9573082489146165
# epoch 47 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch47.pt
# Train Epoch: 48 [0%]	Loss: 0.929592
# epoch 48 training loss: 0.9487255459482019 acc: 0.9580318379160637
# epoch 48 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch48.pt
# Train Epoch: 49 [0%]	Loss: 0.950446
# epoch 49 training loss: 0.9473356631669131 acc: 0.9565846599131693
# epoch 49 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch49.pt
# Train Epoch: 50 [0%]	Loss: 0.921039
# epoch 50 training loss: 0.9461191486228596 acc: 0.9587554269175108
# epoch 50 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch50.pt
# Train Epoch: 51 [0%]	Loss: 0.980834
# epoch 51 training loss: 0.949687434868379 acc: 0.9580318379160637
# epoch 51 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch51.pt
# Train Epoch: 52 [0%]	Loss: 0.969084
# epoch 52 training loss: 0.9452404975891113 acc: 0.9609261939218524
# epoch 52 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch52.pt
# Train Epoch: 53 [0%]	Loss: 0.967019
# epoch 53 training loss: 0.947018561038104 acc: 0.9580318379160637
# epoch 53 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch53.pt
# Train Epoch: 54 [0%]	Loss: 0.959289
# epoch 54 training loss: 0.9482195810838179 acc: 0.9576700434153401
# epoch 54 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch54.pt
# Train Epoch: 55 [0%]	Loss: 0.928556
# epoch 55 training loss: 0.9463569115508687 acc: 0.959479015918958
# epoch 55 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch55.pt
# Train Epoch: 56 [0%]	Loss: 0.921071
# epoch 56 training loss: 0.9445459788495844 acc: 0.9605643994211288
# epoch 56 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch56.pt
# Train Epoch: 57 [0%]	Loss: 0.943111
# epoch 57 training loss: 0.9464970366521315 acc: 0.959479015918958
# epoch 57 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch57.pt
# Train Epoch: 58 [0%]	Loss: 0.933422
# epoch 58 training loss: 0.9462097178805958 acc: 0.9587554269175108
# epoch 58 validation acc: 0.83766234
# saved: ECG_MLP_Pytorch_epoch58.pt
# Train Epoch: 59 [0%]	Loss: 0.945054
# epoch 59 training loss: 0.9468698772517118 acc: 0.959479015918958
# epoch 59 validation acc: 0.8474026
# saved: ECG_MLP_Pytorch_epoch59.pt
# Train Epoch: 60 [0%]	Loss: 0.960503
# epoch 60 training loss: 0.9454044889320027 acc: 0.9591172214182344
# epoch 60 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch60.pt
# Train Epoch: 61 [0%]	Loss: 0.942518
# epoch 61 training loss: 0.9451754716309634 acc: 0.9598408104196816
# epoch 61 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch61.pt
# Train Epoch: 62 [0%]	Loss: 0.936846
# epoch 62 training loss: 0.9464655870741064 acc: 0.9602026049204052
# epoch 62 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch62.pt
# Train Epoch: 63 [0%]	Loss: 0.939243
# epoch 63 training loss: 0.9470324516296387 acc: 0.959479015918958
# epoch 63 validation acc: 0.8798701
# saved: ECG_MLP_Pytorch_epoch63.pt
# Train Epoch: 64 [0%]	Loss: 0.915291
# epoch 64 training loss: 0.9420034641569311 acc: 0.9627351664254703
# epoch 64 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch64.pt
# Train Epoch: 65 [0%]	Loss: 0.921069
# epoch 65 training loss: 0.9402365142648871 acc: 0.9652677279305355
# epoch 65 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch65.pt
# Train Epoch: 66 [0%]	Loss: 0.951295
# epoch 66 training loss: 0.9391120916063135 acc: 0.9681620839363242
# epoch 66 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch66.pt
# Train Epoch: 67 [0%]	Loss: 0.929091
# epoch 67 training loss: 0.939207675782117 acc: 0.965629522431259
# epoch 67 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch67.pt
# Train Epoch: 68 [0%]	Loss: 0.944683
# epoch 68 training loss: 0.9387769157236273 acc: 0.9663531114327062
# epoch 68 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch68.pt
# Train Epoch: 69 [0%]	Loss: 0.940350
# epoch 69 training loss: 0.9386031708934091 acc: 0.9670767004341534
# epoch 69 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch69.pt
# Train Epoch: 70 [0%]	Loss: 0.929184
# epoch 70 training loss: 0.9376106397672133 acc: 0.9685238784370478
# epoch 70 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch70.pt
# Train Epoch: 71 [0%]	Loss: 0.935852
# epoch 71 training loss: 0.9362561187960885 acc: 0.9696092619392185
# epoch 71 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch71.pt
# Train Epoch: 72 [0%]	Loss: 0.921716
# epoch 72 training loss: 0.9373986260457472 acc: 0.9688856729377714
# epoch 72 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch72.pt
# Train Epoch: 73 [0%]	Loss: 0.914197
# epoch 73 training loss: 0.9355100528760389 acc: 0.9699710564399421
# epoch 73 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch73.pt
# Train Epoch: 74 [0%]	Loss: 0.914358
# epoch 74 training loss: 0.9354048046198759 acc: 0.9699710564399421
# epoch 74 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch74.pt
# Train Epoch: 75 [0%]	Loss: 0.929064
# epoch 75 training loss: 0.9361076300794428 acc: 0.9699710564399421
# epoch 75 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch75.pt
# Train Epoch: 76 [0%]	Loss: 0.913320
# epoch 76 training loss: 0.9375130479986017 acc: 0.9681620839363242
# epoch 76 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch76.pt
# Train Epoch: 77 [0%]	Loss: 0.953244
# epoch 77 training loss: 0.9365608096122742 acc: 0.9696092619392185
# epoch 77 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch77.pt
# Train Epoch: 78 [0%]	Loss: 0.920575
# epoch 78 training loss: 0.936853677034378 acc: 0.967438494934877
# epoch 78 validation acc: 0.84090906
# saved: ECG_MLP_Pytorch_epoch78.pt
# Train Epoch: 79 [0%]	Loss: 0.931979
# epoch 79 training loss: 0.9374273473566229 acc: 0.9681620839363242
# epoch 79 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch79.pt
# Train Epoch: 80 [0%]	Loss: 0.921232
# epoch 80 training loss: 0.9351894449103962 acc: 0.9706946454413893
# epoch 80 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch80.pt
# Train Epoch: 81 [0%]	Loss: 0.920794
# epoch 81 training loss: 0.9336646172133359 acc: 0.9710564399421129
# epoch 81 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch81.pt
# Train Epoch: 82 [0%]	Loss: 0.921335
# epoch 82 training loss: 0.9324298094619404 acc: 0.9732272069464544
# epoch 82 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch82.pt
# Train Epoch: 83 [0%]	Loss: 0.937169
# epoch 83 training loss: 0.9339295761151747 acc: 0.9714182344428365
# epoch 83 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch83.pt
# Train Epoch: 84 [0%]	Loss: 0.928469
# epoch 84 training loss: 0.932813744653355 acc: 0.9721418234442837
# epoch 84 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch84.pt
# Train Epoch: 85 [0%]	Loss: 0.944203
# epoch 85 training loss: 0.9335662478750403 acc: 0.9725036179450073
# epoch 85 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch85.pt
# Train Epoch: 86 [0%]	Loss: 0.941296
# epoch 86 training loss: 0.9359809485348788 acc: 0.9699710564399421
# epoch 86 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch86.pt
# Train Epoch: 87 [0%]	Loss: 0.912964
# epoch 87 training loss: 0.9370446774092588 acc: 0.9688856729377714
# epoch 87 validation acc: 0.8668831
# saved: ECG_MLP_Pytorch_epoch87.pt
# Train Epoch: 88 [0%]	Loss: 0.926669
# epoch 88 training loss: 0.93785144795071 acc: 0.9678002894356006
# epoch 88 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch88.pt
# Train Epoch: 89 [0%]	Loss: 0.933231
# epoch 89 training loss: 0.9333572929555719 acc: 0.9710564399421129
# epoch 89 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch89.pt
# Train Epoch: 90 [0%]	Loss: 0.944328
# epoch 90 training loss: 0.9335919537327506 acc: 0.9717800289435601
# epoch 90 validation acc: 0.85064936
# saved: ECG_MLP_Pytorch_epoch90.pt
# Train Epoch: 91 [0%]	Loss: 0.955885
# epoch 91 training loss: 0.9353997869925066 acc: 0.9699710564399421
# epoch 91 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch91.pt
# Train Epoch: 92 [0%]	Loss: 0.931766
# epoch 92 training loss: 0.9337552975524556 acc: 0.9714182344428365
# epoch 92 validation acc: 0.85714287
# saved: ECG_MLP_Pytorch_epoch92.pt
# Train Epoch: 93 [0%]	Loss: 0.938265
# epoch 93 training loss: 0.9342657869512384 acc: 0.9696092619392185
# epoch 93 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch93.pt
# Train Epoch: 94 [0%]	Loss: 0.944660
# epoch 94 training loss: 0.9326929585500197 acc: 0.9732272069464544
# epoch 94 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch94.pt
# Train Epoch: 95 [0%]	Loss: 0.922578
# epoch 95 training loss: 0.9303204796530984 acc: 0.9750361794500724
# epoch 95 validation acc: 0.8636364
# saved: ECG_MLP_Pytorch_epoch95.pt
# Train Epoch: 96 [0%]	Loss: 0.942193
# epoch 96 training loss: 0.9316142255609686 acc: 0.9739507959479016
# epoch 96 validation acc: 0.8538961
# saved: ECG_MLP_Pytorch_epoch96.pt
# Train Epoch: 97 [0%]	Loss: 0.933416
# epoch 97 training loss: 0.9299301342530684 acc: 0.9764833574529667
# epoch 97 validation acc: 0.8603896
# saved: ECG_MLP_Pytorch_epoch97.pt
# Train Epoch: 98 [0%]	Loss: 0.917846
# epoch 98 training loss: 0.9304133491082625 acc: 0.9739507959479016
# epoch 98 validation acc: 0.8701299
# saved: ECG_MLP_Pytorch_epoch98.pt
# Train Epoch: 99 [0%]	Loss: 0.938172
# epoch 99 training loss: 0.9299796575849707 acc: 0.975397973950796
# epoch 99 validation acc: 0.84415585
# saved: ECG_MLP_Pytorch_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 63

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.8959688
# Sensitivity [0.8125     0.90259743 0.89041096 0.96721309 0.92982459]
# Precision [0.89375001 0.85276073 0.87837839 0.86764705 0.98148149]
# Confusion
#  [[143.  16.   9.   5.   3.]
#  [ 10. 139.   1.   4.   0.]
#  [  3.   4. 130.   9.   0.]
#  [  1.   1.   2. 118.   0.]
#  [  3.   3.   6.   0. 159.]]
